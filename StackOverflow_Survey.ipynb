# %%
#libraries
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 84)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df[['Age', 'Employment']]
# Out:
#                       Age                                         Employment
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# 2         45-54 years old                                Employed, full-time
# 3         25-34 years old                                Employed, full-time
# 4         25-34 years old  Employed, full-time;Independent contractor, fr...
# ...                   ...                                                ...
# 89179     25-34 years old  Employed, full-time;Independent contractor, fr...
# 89180     18-24 years old             Student, full-time;Employed, part-time
# 89181   Prefer not to say                                I prefer not to say
# 89182  Under 18 years old             Employed, part-time;Student, part-time
# 89183     35-44 years old                                Employed, full-time
#
# [89184 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df.loc[0:26, ['Age', 'EdLevel']]
# Out:
#                    Age                                            EdLevel
# 0      18-24 years old                                                NaN
# 1      25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      45-54 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3      25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4      25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5      35-44 years old  Some college/university study without earning ...
# 6      35-44 years old  Some college/university study without earning ...
# 7      25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8      45-54 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9      25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10     25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11     25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
df['Age']
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
df.set_index('Age', inplace=True)

# %%
df
# Out:
#                     ResponseId     Q120                      MainBranch  \
# Age
# 18-24 years old              1  I agree                   None of these
# 25-34 years old              2  I agree  I am a developer by profession
# 45-54 years old              3  I agree  I am a developer by profession
# 25-34 years old              4  I agree  I am a developer by profession
# 25-34 years old              5  I agree  I am a developer by profession
# ...                        ...      ...                             ...
# 25-34 years old          89180  I agree  I am a developer by profession
# 18-24 years old          89181  I agree  I am a developer by profession
# Prefer not to say        89182  I agree     I code primarily as a hobby
# Under 18 years old       89183  I agree  I am a developer by profession
# 35-44 years old          89184  I agree  I am a developer by profession
#
#                                                            Employment  \
# Age
# ...

# %%
df.loc['45-54 years old', 'Q120']
# Out:
# Age
# 45-54 years old    I agree
# 45-54 years old    I agree
# 45-54 years old    I agree
# 45-54 years old    I agree
# 45-54 years old    I agree
#                     ...
# 45-54 years old    I agree
# 45-54 years old    I agree
# 45-54 years old    I agree
# 45-54 years old    I agree
# 45-54 years old    I agree
# Name: Q120, Length: 8334, dtype: object

# %%
df.iloc[0]
# Out:
# ResponseId                                         1
# Q120                                         I agree
# MainBranch                             None of these
# Employment                                       NaN
# RemoteWork                                       NaN
# CodingActivities                                 NaN
# EdLevel                                          NaN
# LearnCode                                        NaN
# LearnCodeOnline                                  NaN
# LearnCodeCoursesCert                             NaN
# YearsCode                                        NaN
# YearsCodePro                                     NaN
# DevType                                          NaN
# OrgSize                                          NaN
# PurchaseInfluence                                NaN
# TechList                                         NaN
# BuyNewTool                                       NaN
# Country                                          NaN
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#                       Age  ResponseId     Q120  \
# 0         18-24 years old           1  I agree
# 1         25-34 years old           2  I agree
# 2         45-54 years old           3  I agree
# 3         25-34 years old           4  I agree
# 4         25-34 years old           5  I agree
# ...                   ...         ...      ...
# 89179     25-34 years old       89180  I agree
# 89180     18-24 years old       89181  I agree
# 89181   Prefer not to say       89182  I agree
# 89182  Under 18 years old       89183  I agree
# 89183     35-44 years old       89184  I agree
#
#                            MainBranch  \
# 0                       None of these
# 1      I am a developer by profession
# 2      I am a developer by profession
# 3      I am a developer by profession
# 4      I am a developer by profession
# ...                               ...
# 89179  I am a developer by profession
# 89180  I am a developer by profession
# 89181     I code primarily as a hobby
# ...

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col='ResponseId')
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %% [markdown]
# ## Example:

# %%
people = {
   "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Doe"],
   "email": ["CoreyMSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]
}

# %%
import pandas as pd

# %%
 df = pd.DataFrame(people)
 df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
filt = (df['last'] == 'Schafer') | (df['first'] == 'John')
filt
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
df[filt]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df.loc[filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ## ----------------------------------------------------------------------

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col='ResponseId')
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
high_salary = (df['ConvertedCompYearly'] > 70000)

# %%
df.loc[high_salary, ['Country','DevType', 'LanguageHaveWorkedWith']]
# Out:
#                                                       Country  \
# ResponseId
# 2                                    United States of America
# 3                                    United States of America
# 4                                    United States of America
# 6           United Kingdom of Great Britain and Northern I...
# 7                                    United States of America
# ...                                                       ...
# 89144                                United States of America
# 89145                                                 Austria
# 89155                                United States of America
# 89157                                United States of America
# 89158                                                  Canada
#
#                                          DevType  \
# ResponseId
# 2           Senior Executive (C-Suite, VP, etc.)
# 3                            Developer, back-end
# ...

# %%
filt  = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.rename(columns={'RemoteWork': 'Remote'}, inplace= True)
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.loc[2]
# Out:
# Q120                                                                             I agree
# MainBranch                                                I am a developer by profession
# Age                                                                      25-34 years old
# Employment                                                           Employed, full-time
# Remote                                                                            Remote
# CodingActivities                       Hobby;Contribute to open-source projects;Boots...
# EdLevel                                     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                              Books / Physical media;Colleague;Friend or fam...
# LearnCodeOnline                        Formal documentation provided by the owner of ...
# LearnCodeCoursesCert                                                               Other
# ...

# %%
df['MainBranch'].apply(len)
# Out:
# ResponseId
# 1        13
# 2        30
# 3        30
# 4        30
# 5        30
#          ..
# 89180    30
# 89181    30
# 89182    27
# 89183    30
# 89184    30
# Name: MainBranch, Length: 89184, dtype: int64

# %%
df['Age'] + '        ' + df['EdLevel']
# Out:
# ResponseId
# 1                                                      NaN
# 2        25-34 years old        Bachelor’s degree (B.A....
# 3        45-54 years old        Bachelor’s degree (B.A....
# 4        25-34 years old        Bachelor’s degree (B.A....
# 5        25-34 years old        Bachelor’s degree (B.A....
#                                ...
# 89180    25-34 years old        Associate degree (A.A.,...
# 89181    18-24 years old        Bachelor’s degree (B.A....
# 89182              Prefer not to say        Something else
# 89183    Under 18 years old        Secondary school (e....
# 89184    35-44 years old        Bachelor’s degree (B.A....
# Length: 89184, dtype: object

# %%
df['Stage'] = df['Age'] + '        ' + df['EdLevel']
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.drop(columns=['Age'])
# Out:
#                Q120                      MainBranch  \
# ResponseId
# 1           I agree                   None of these
# 2           I agree  I am a developer by profession
# 3           I agree  I am a developer by profession
# 4           I agree  I am a developer by profession
# 5           I agree  I am a developer by profession
# ...             ...                             ...
# 89180       I agree  I am a developer by profession
# 89181       I agree  I am a developer by profession
# 89182       I agree     I code primarily as a hobby
# 89183       I agree  I am a developer by profession
# 89184       I agree  I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# ...

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.drop(index=89180)
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89179       I agree  I am a developer by profession     45-54 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.sort_values(by='Country', inplace=True)

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 21498       I agree  I am a developer by profession     35-44 years old
# 65293       I agree  I am a developer by profession     35-44 years old
# 1335        I agree  I am a developer by profession     18-24 years old
# 33928       I agree  I am a developer by profession     18-24 years old
# 77723       I agree     I code primarily as a hobby  Under 18 years old
# ...             ...                             ...                 ...
# 88821       I agree                   None of these     35-44 years old
# 88829       I agree                   None of these     25-34 years old
# 88831       I agree                   None of these     18-24 years old
# 89029       I agree                   None of these     45-54 years old
# 89160       I agree                   None of these   Prefer not to say
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.nlargest(20, 'ConvertedCompYearly')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 53269       I agree                     I am a developer by profession
# 77849       I agree                     I am a developer by profession
# 66224       I agree                     I am a developer by profession
# 28122       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 55103       I agree  I am not primarily a developer, but I write co...
# 80587       I agree                     I am a developer by profession
# 83680       I agree                     I am a developer by profession
# 47798       I agree                     I am a developer by profession
# 88348       I agree                     I am a developer by profession
# 64973       I agree                     I am a developer by profession
# 771         I agree                     I am a developer by profession
# ...

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# ResponseId
# 21498        NaN
# 65293        NaN
# 1335      2403.0
# 33928        NaN
# 77723        NaN
# 86039    68000.0
# 10377        NaN
# 83821        NaN
# 73714        NaN
# 61453        NaN
# 21673        NaN
# 55302        NaN
# 62550        NaN
# 84341        NaN
# 47692        NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 74963.0

# %%
df.describe()
# Out:
#           CompTotal       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df['ConvertedCompYearly'].count()
# Out:
# 48019

# %%
df['CodingActivities']
# Out:
# ResponseId
# 21498    Contribute to open-source projects;Freelance/c...
# 65293                        Hobby;Freelance/contract work
# 1335     Professional development or self-paced learnin...
# 33928                                                  NaN
# 77723                                                  NaN
#                                ...
# 88821                                                  NaN
# 88829                                                  NaN
# 88831                                                  NaN
# 89029                                                  NaN
# 89160                                                  NaN
# Name: CodingActivities, Length: 89184, dtype: object

# %%
df['DevType'].value_counts(normalize=True)
# Out:
# DevType
# Developer, full-stack                            0.334777
# Developer, back-end                              0.178804
# Developer, front-end                             0.065967
# Developer, desktop or enterprise applications    0.050786
# Other (please specify):                          0.040067
# Developer, mobile                                0.033783
# Engineering manager                              0.026447
# Student                                          0.025965
# Developer, embedded applications or devices      0.024001
# Data scientist or machine learning specialist    0.020658
# DevOps specialist                                0.018043
# Academic researcher                              0.017614
# Research & Development role                      0.017601
# Senior Executive (C-Suite, VP, etc.)             0.017328
# Engineer, data                                   0.016235
# Cloud infrastructure engineer                    0.013477
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Germany')
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 65679       I agree  I am a developer by profession  25-34 years old
# 58621       I agree  I am a developer by profession  35-44 years old
# 54326       I agree  I am a developer by profession  18-24 years old
# 25588       I agree  I am a developer by profession  25-34 years old
# 65689       I agree  I am a developer by profession  25-34 years old
# ...             ...                             ...              ...
# 15941       I agree  I am a developer by profession  25-34 years old
# 22598       I agree  I am a developer by profession  18-24 years old
# 22635       I agree  I am a developer by profession  45-54 years old
# 22628       I agree  I am a developer by profession  45-54 years old
# 41054       I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['DevType'].value_counts()
# Out:
# DevType
# Developer, full-stack                            1523
# Developer, back-end                               882
# Developer, front-end                              484
# Developer, mobile                                 289
# Student                                           175
# Developer, desktop or enterprise applications     137
# Other (please specify):                           116
# Data scientist or machine learning specialist     110
# Engineering manager                                89
# Engineer, data                                     71
# Research & Development role                        59
# DevOps specialist                                  58
# Developer, embedded applications or devices        53
# Senior Executive (C-Suite, VP, etc.)               47
# Developer, QA or test                              45
# Data or business analyst                           43
# Project manager                                    42
# ...

# %%
filt = df['Country'] == 'Germany'
df.loc[filt]['DevType'].value_counts()
# Out:
# DevType
# Developer, full-stack                            2075
# Developer, back-end                               957
# Developer, desktop or enterprise applications     446
# Developer, front-end                              331
# Academic researcher                               272
# Other (please specify):                           237
# Student                                           229
# Developer, embedded applications or devices       216
# Developer, mobile                                 169
# Engineering manager                               142
# DevOps specialist                                 132
# Research & Development role                       112
# Data scientist or machine learning specialist     111
# Senior Executive (C-Suite, VP, etc.)              108
# Cloud infrastructure engineer                     102
# Engineer, data                                    101
# System administrator                               88
# ...

# %%
country_grp['DevType'].value_counts().loc['Germany']
# Out:
# DevType
# Developer, full-stack                            2075
# Developer, back-end                               957
# Developer, desktop or enterprise applications     446
# Developer, front-end                              331
# Academic researcher                               272
# Other (please specify):                           237
# Student                                           229
# Developer, embedded applications or devices       216
# Developer, mobile                                 169
# Engineering manager                               142
# DevOps specialist                                 132
# Research & Development role                       112
# Data scientist or machine learning specialist     111
# Senior Executive (C-Suite, VP, etc.)              108
# Cloud infrastructure engineer                     102
# Engineer, data                                    101
# System administrator                               88
# ...

# %%
country_grp['DevType'].value_counts(normalize=True).loc['Germany']
# Out:
# DevType
# Developer, full-stack                            0.327908
# Developer, back-end                              0.151233
# Developer, desktop or enterprise applications    0.070480
# Developer, front-end                             0.052307
# Academic researcher                              0.042984
# Other (please specify):                          0.037453
# Student                                          0.036188
# Developer, embedded applications or devices      0.034134
# Developer, mobile                                0.026707
# Engineering manager                              0.022440
# DevOps specialist                                0.020860
# Research & Development role                      0.017699
# Data scientist or machine learning specialist    0.017541
# Senior Executive (C-Suite, VP, etc.)             0.017067
# Cloud infrastructure engineer                    0.016119
# Engineer, data                                   0.015961
# ...

# %%
country_grp['ConvertedCompYearly'].median().loc['Germany']
# Out:
# 74963.0

# %%
country_grp['ConvertedCompYearly'].agg(['median', 'mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                             915.0  843636.090909
# Albania                               10741.0   29219.450000
# Algeria                                8782.0   10069.190476
# Andorra                               42836.0  120368.800000
# Angola                                 4302.0    4302.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...  12000.0   23068.851852
# Viet Nam                              12763.0   20995.956140
# Yemen                                  6500.0   15089.333333
# Zambia                                 9687.0   13897.800000
# Zimbabwe                              12500.0   26740.000000
#
# [185 rows x 2 columns]

# %%
country_grp['ConvertedCompYearly'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     89222.000000
# mean      142136.677435
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'Germany'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 3686

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 185, dtype: int64

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18647
# Germany                                              7328
# India                                                5625
# United Kingdom of Great Britain and Northern Ir...   5552
# Canada                                               3507
# ...                                                   ...
# Grenada                                                 1
# Guinea-Bissau                                           1
# Liechtenstein                                           1
# Marshall Islands                                        1
# Saint Kitts and Nevis                                   1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
python_df.to_csv('data/modified.csv')

# %%
python_df.to_excel('data/modified.xlsx')

# %%
python_df.to_json('data/modified.json')
